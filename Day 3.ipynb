# %% [markdown]
# ### Day 2 math for ml practice

# %%
import numpy as np
# Out:
# [1 2 3]

# %% [markdown]
# #### Vecror in R3

# %%
v = np.array([1,0,-2])
print(v)
# Out:
# [ 1  0 -2]

# %% [markdown]
# #### vector in R5

# %%
v = np.array([1,2,3,4,5])
print(v)
# Out:
# [1 2 3 4 5]

# %% [markdown]
# #### check dimension of vector

# %%
v.shape
# Out:
# (5,)

# %%
v = np.zeros(3)
print(v)
# Out:
# [0. 0. 0.]

# %%
# unit vector (manually)
v = np.array([3,4])
unit_v = v / np.linalg.norm(v)
print(unit_v)
# Out:
# [0.6 0.8]

# %%
# vector magnitude (norm)
print(np.linalg.norm(v))
# Out:
# 5.0

# %%
# random vector in R4 
v = np.random.rand(4)
print(v)
# Out:
# [0.6145573  0.90233828 0.75048974 0.73947041]

# %%
# access vector elements 
v = np.array([10,20,30])
print(v[0],v[1])
print(v[0] + v[2])
# Out:
# 10 20
# 40

# %%
# negative vector 
v = np.array([1,-2,3])
print(-v)
# Out:
# [-1  2 -3]

# %%
# convert list -> vector 
lst = [5,6,7]
v = np.array(lst)
print(v)
# Out:
# [5 6 7]
